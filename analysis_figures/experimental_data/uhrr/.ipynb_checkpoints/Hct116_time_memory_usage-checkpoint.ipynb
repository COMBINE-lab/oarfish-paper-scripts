# %%
import re
import matplotlib.pyplot as plt
import pandas as pd
from os.path import join
import seaborn as sns
from matplotlib.gridspec import GridSpec

# %%
def extract_max_resident_set_size(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        match = re.search(r"Maximum resident set size \(kbytes\): (\d+)", content)
        if match:
            return int(match.group(1))
        else:
            return None

# %%
def extract_wall_clock_time(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        match = re.search(r'Elapsed \(wall clock\) time \(h:mm:ss or m:ss\): (\S+)', content)
        if match:
            wall_clock_time = match.group(1)
            #print(wall_clock_time)
            # Split the time into hours, minutes, and seconds
            time_parts = wall_clock_time.split(':')
            
            # Initialize variables for hours, minutes, and seconds
            hours = 0
            minutes = 0
            seconds = 0

            # Assign values based on the number of time parts
            if len(time_parts) == 3:
                hours = int(time_parts[0])
                minutes = int(time_parts[1])
                seconds = float(time_parts[2])
            elif len(time_parts) == 2:
                minutes = int(time_parts[0])
                seconds = float(time_parts[1])
            elif len(time_parts) == 1:
                seconds = float(time_parts[0])

            # Convert to total seconds
            total_seconds = hours * 3600 + minutes * 60 + seconds
            return total_seconds
        else:
            return None

# %%
def plot_function(input_list):
    
    fig = plt.figure(figsize=(12,10))
    gs = GridSpec(2, 3, width_ratios=[1, 1, 0.2])  # 2 rows, 3 columns; last column for legend

    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[1, 0])
    ax4 = fig.add_subplot(gs[1, 1])
    ax_legend = fig.add_subplot(gs[:, 2])  # This will be the space for the legend
    ax_legend.axis('off')  # Turn off the axis for the legend
    
    color_palette = sns.color_palette("dark", 5)
    marker_palette = ['o', '^', 's', 'p', 'h', '+', 'x', '*']
    
    legend_handles = []
    legend_labels = []
    
    cl = 0
    ml = 0
    
    for v1, v2 in {'directcDNA': 'direct cDNA', "directRNA": "direct RNA"}.items():
        line, = ax1.plot(list(input_list[v1]['Method']), list(input_list[v1]['time']), 
                         marker=marker_palette[ml], ms=6, linestyle='-', color=color_palette[cl], label=f"{v2}")
        legend_handles.append(line)
        legend_labels.append(f"{v2}")
        cl += 1
        ml += 1
    ax1.set_xlabel('Method', fontsize=10)
    ax1.set_ylabel('Elapsed Time (seconds)', fontsize=10)
    ax1.set_title('Elapsed Time for all methods', fontsize=10)
    ax1.grid(True)  # Add grid lines
    ax1.set_xticklabels(list(input_list[v1]['Method']), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
    ax1.text(0.0, 1.05, 'a)', transform=ax1.transAxes, ha="left", va="center", fontsize=12, weight="bold")
    
    cl = 0
    ml = 0
    
    for v1, v2 in {'directcDNA': 'direct cDNA', "directRNA": "direct RNA"}.items():
        line, = ax2.plot(list(input_list[v1]['Method']), list(input_list[v1]['memory']), 
                         marker=marker_palette[ml], ms=6, linestyle='-', color=color_palette[cl], label=f"{v2}")
        cl += 1
        ml += 1
    ax2.set_xlabel('Method', fontsize=10)
    ax2.set_ylabel('Memory Usage (kbytes)', fontsize=10)
    ax2.set_title('Memory Usage for all methods', fontsize=10)
    ax2.grid(True)  # Add grid lines
    ax2.set_xticklabels(list(input_list[v1]['Method']), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
    ax2.text(0.0, 1.1, 'b)', transform=ax2.transAxes, ha="left", va="center", fontsize=12, weight="bold")
    
    cl = 0
    ml = 0
    
    for v1, v2 in {'directcDNA': 'direct cDNA', "directRNA": "direct RNA"}.items():
        line, = ax3.plot(list(input_list[v1]['Method'][:-1]), list(input_list[v1]['time'][:-1]), 
                         marker=marker_palette[ml], ms=6, linestyle='-', color=color_palette[cl], label=f"{v2}")
        cl += 1
        ml += 1
    ax3.set_xlabel('Method', fontsize=10)
    ax3.set_ylabel('Elapsed Time (seconds)', fontsize=10)
    ax3.set_title('Elapsed Time (Excludes ESPRESSO)', fontsize=10)
    ax3.grid(True)  # Add grid lines
    ax3.set_xticklabels(list(input_list[v1]['Method'][:-1]), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
    ax3.text(0.0, 1.05, 'c)', transform=ax3.transAxes, ha="left", va="center", fontsize=12, weight="bold")
    
    cl = 0
    ml = 0
    
    for v1, v2 in {'directcDNA': 'direct cDNA', "directRNA": "direct RNA"}.items():
        line, = ax4.plot(list(input_list[v1]['Method'][:-1]), list(input_list[v1]['memory'][:-1]), 
                         marker=marker_palette[ml], ms=6, linestyle='-', color=color_palette[cl], label=f"{v2}")
        cl += 1
        ml += 1
    ax4.set_xlabel('Method', fontsize=10)
    ax4.set_ylabel('Memory Usage (kbytes)', fontsize=10)
    ax4.set_title('Memory Usage (Excludes ESPRESSO)', fontsize=10)
    ax4.grid(True)  # Add grid lines
    ax4.set_xticklabels(list(input_list[v1]['Method'][:-1]), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
    ax4.text(0.0, 1.1, 'd)', transform=ax4.transAxes, ha="left", va="center", fontsize=12, weight="bold")
    
    plt.tight_layout()
    
    # Create the single legend outside the subplots
    ax_legend.legend(handles=legend_handles, labels=legend_labels, loc='center', fontsize=10)
    
    plt.show()

# %%
file_path_quant = "/mnt/scratch2/zahra/sim_quant/nanosim_quant"
d = {'H9_1DcDNA': 'cdna', "H9_directRNA": "drna", 'NA12878_1DcDNA': 'cdna', "NA12878_directRNA": "drna"} 
method_list = ["oarfish align (cov)", "oarfish align (nocov)", "oarfish raw (cov)", "oarfish raw (nocov)", "NanoCount", "NanoCount (nofilt)", "bambu", "lr-kallisto", "TranSigner", "IsoQuant", "ESPRESSO"]

final_df = {}

for k, v in d.items():
    final_df[k] = pd.DataFrame()
    final_df[k]["Method"] = method_list
    
    #shr dataset
    file_path = {}
    file_path = {'oarfish align (cov)':     join(file_path_quant, f"oarfish_align_quant/{k}/{v}/time_cov"),
                 'oarfish align (nocov)':   join(file_path_quant, f"oarfish_align_quant/{k}/{v}/time_nocov"),
                 'oarfish raw (cov)':       join(file_path_quant, f"oarfish_raw_quant/{k}/{v}/time_cov"),
                 'oarfish raw (nocov)':     join(file_path_quant, f"oarfish_raw_quant/{k}/{v}/time_nocov"),
                 'NanoCount':               join(file_path_quant, f"NanoCount_quant/{k}/{v}"),
                 'NanoCount (nofilt)':      join(file_path_quant, f"NanoCount_quant_nofilt/{k}/{v}"),
                 'bambu':                   join(file_path_quant, f"bambu_quant/{k}/{v}/time_info"),
                 'lr-kallisto':             join(file_path_quant, f"lr-kallisto/{k}/{v}"),
                 'TranSigner':              join(file_path_quant, f"transigner_quant/{k}/{v}"),
                 'IsoQuant':                join(file_path_quant, f"IsoQuant_quant/{k}/{v}/time_info"),
                 'ESPRESSO':                join(file_path_quant, f"espresso_quant/{k}/{v}")}
    
    align_path = {'align_T':                 join(file_path_quant, f"alignment/{k}/{v}_time_T"),
                  'align_G':                 join(file_path_quant, f"alignment/{k}/{v}_time_G")}
    
    elapsed_time = []
    memory_usage = []
    for method, path in file_path.items():
        if method in ["oarfish align (cov)", "oarfish align (nocov)"]:
            elapsed_time.append(extract_wall_clock_time(path) + extract_wall_clock_time(align_path['align_T']))
            memory_usage.append(extract_max_resident_set_size(path) + extract_max_resident_set_size(align_path['align_T']))
        elif method in ["oarfish raw (cov)", "oarfish raw (nocov)"]:
            elapsed_time.append(extract_wall_clock_time(path))
            memory_usage.append(extract_max_resident_set_size(path))
        elif method == "NanoCount":
            elapsed_time.append(extract_wall_clock_time(path + "/index_time_info") + extract_wall_clock_time(path + "/sort_time_info") + extract_wall_clock_time(path + "/time_info") + extract_wall_clock_time(align_path['align_T']))
            memory_usage.append(extract_max_resident_set_size(path + "/index_time_info") + extract_max_resident_set_size(path + "/sort_time_info") + extract_max_resident_set_size(path + "/time_info") + extract_max_resident_set_size(align_path['align_T']))
        elif method == "NanoCount (nofilt)":
            elapsed_time.append(extract_wall_clock_time(file_path["NanoCount"] + "/index_time_info") + extract_wall_clock_time(file_path["NanoCount"] + "/sort_time_info") + extract_wall_clock_time(path + "/time_info") + extract_wall_clock_time(align_path['align_T']))
            memory_usage.append(extract_max_resident_set_size(file_path["NanoCount"] + "/index_time_info") + extract_max_resident_set_size(file_path["NanoCount"] + "/sort_time_info") + extract_max_resident_set_size(path + "/time_info") + extract_max_resident_set_size(align_path['align_T']))
        elif method == "lr-kallisto":
            elapsed_time.append(extract_wall_clock_time(file_path_quant + '/lr-kallisto/time_kallisto_index') + extract_wall_clock_time(path + '/time_kallisto_bus') + extract_wall_clock_time(path + '/time_bustools_sort') + extract_wall_clock_time(path + '/time_bustools_count') + extract_wall_clock_time(path + '/time_kallisto_quant') + extract_wall_clock_time(path + '/time_kallisto_convert'))
            memory_usage.append(extract_max_resident_set_size(file_path_quant + '/lr-kallisto/time_kallisto_index') + extract_max_resident_set_size(path + '/time_kallisto_bus') + extract_max_resident_set_size(path + '/time_bustools_sort') + extract_max_resident_set_size(path + '/time_bustools_count') + extract_max_resident_set_size(path + '/time_kallisto_quant') + extract_max_resident_set_size(path + '/time_kallisto_convert'))
        elif method == "TranSigner":
            elapsed_time.append(extract_wall_clock_time(path+"/time_align") + extract_wall_clock_time(path+"/time_prefilter") + extract_wall_clock_time(path+"/time_em"))
            memory_usage.append(extract_max_resident_set_size(path+"/time_align") + extract_max_resident_set_size(path+"/time_prefilter") + extract_max_resident_set_size(path+"/time_em")) 
        elif method == "ESPRESSO":
            elapsed_time.append(extract_wall_clock_time(path+"/time_ESPRESSO_S") + extract_wall_clock_time(path+"/time_ESPRESSO_C") + extract_wall_clock_time(path+"/time_ESPRESSO_Q") + extract_wall_clock_time(path+"/time_sort") + extract_wall_clock_time(align_path['align_G']))
            memory_usage.append(extract_max_resident_set_size(path+"/time_ESPRESSO_S") + extract_max_resident_set_size(path+"/time_ESPRESSO_C") + extract_max_resident_set_size(path+"/time_ESPRESSO_Q") + + extract_max_resident_set_size(path+"/time_sort") + extract_max_resident_set_size(align_path['align_G']))            
        else:
            elapsed_time.append(extract_wall_clock_time(path) + extract_wall_clock_time(align_path['align_G']))
            memory_usage.append(extract_max_resident_set_size(path) + extract_max_resident_set_size(align_path['align_G']))
            
    final_df[k]["time"] = elapsed_time
    final_df[k]["memory"] = memory_usage

# %%
final_df
# Out:
# {'H9_1DcDNA':                    Method       time     memory
#  0     oarfish align (cov)    2423.00   11607232
#  1   oarfish align (nocov)    2552.33   11502752
#  2       oarfish raw (cov)    1637.97    5391060
#  3     oarfish raw (nocov)    1024.42    5263924
#  4               NanoCount    3887.10   42436796
#  5      NanoCount (nofilt)    4414.55   63559188
#  6                   bambu    5127.89   45697004
#  7             lr-kallisto    1113.10    9720120
#  8              TranSigner    6033.00   53517784
#  9                IsoQuant   12598.34   54829756
#  10               ESPRESSO  137789.22  224787832,
#  'H9_directRNA':                    Method      time     memory
#  0     oarfish align (cov)   3039.03   13425560
#  1   oarfish align (nocov)   3064.80   13335792
#  2       oarfish raw (cov)    760.46    5669720
#  3     oarfish raw (nocov)   1793.19    5549316
#  4               NanoCount   5099.77   46043248
#  5      NanoCount (nofilt)   5620.61   67625240
#  6                   bambu   6375.86   49140384
#  7             lr-kallisto   1482.23    9706360
#  8              TranSigner  14032.09   56129812
#  9                IsoQuant  34660.86   53529572
#  10               ESPRESSO  72716.07  226921972,
#  'NA12878_1DcDNA':                    Method      time     memory
#  0     oarfish align (cov)   6522.82   11319624
#  1   oarfish align (nocov)   6532.55   11223136
#  2       oarfish raw (cov)   1053.81    5089968
#  3     oarfish raw (nocov)    758.41    5081444
#  4               NanoCount   7608.67   39991712
#  5      NanoCount (nofilt)   8095.84   59024112
#  6                   bambu   4259.38   43595536
#  7             lr-kallisto   1556.36    9751852
#  8              TranSigner   8508.57   49405764
#  9                IsoQuant  11563.39   55393456
#  10               ESPRESSO  51892.97  209850100,
#  'NA12878_directRNA':                    Method      time     memory
#  0     oarfish align (cov)   1736.30   12628164
#  1   oarfish align (nocov)   1787.10   12514532
#  2       oarfish raw (cov)   1671.00    5039720
#  3     oarfish raw (nocov)   1201.16    4956716
#  4               NanoCount   3258.84   42963244
#  5      NanoCount (nofilt)   3641.79   57399248
#  6                   bambu  12017.30   42186280
#  7             lr-kallisto   1256.56    9679928
#  8              TranSigner   3939.07   46810288
#  9                IsoQuant  30558.00   54010380
#  10               ESPRESSO  87614.07  210454356}

# %%
plot_function(final_df)
# Out:
# /mnt/scratch7/zahra/tmp/ipykernel_508624/626468269.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(list(input_list[v1]['Method']), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
# /mnt/scratch7/zahra/tmp/ipykernel_508624/626468269.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(list(input_list[v1]['Method']), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
# /mnt/scratch7/zahra/tmp/ipykernel_508624/626468269.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(list(input_list[v1]['Method'][:-1]), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
# /mnt/scratch7/zahra/tmp/ipykernel_508624/626468269.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(list(input_list[v1]['Method'][:-1]), rotation=45, fontsize=10, ha='right')  # Rotate x-axis labels for readability
